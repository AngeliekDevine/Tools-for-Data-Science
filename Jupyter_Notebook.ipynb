# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Angeliek Devine__ <br> Weapon Systems Engineer

# %% [markdown]
# _I am interested in data science because I would like to be able to build fun projects in a variaty of languages including python, C, C++, Matlab, etc._

# %% [markdown]
# ### My code computes the sum of 3 and 2.

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# | Cat Name(s) | Adoption Location | Picture (with link) |
# |:---:|:---:|:---:|
# | Ben & Jerry | Boston, MA | [<div> <img src="attachment:86eb0c59-6202-4a63-a3a3-cc8855002c47.jpg" width="100"/> </div>](https://www.petfinder.com/cat/ben-and-jerry-58811912/ma/boston/project-saving-paws-fl1823/) |
# | Paxton | Washington, DC | [<div> <img src="attachment:6a4eaa26-0da2-4abd-8037-120527580c9b.jpeg" width="100"/> </div>](https://adopt.adopets.com/pet/faf6e7a2-f503-448c-a2b3-be998afb719c?tracking=d25f95d0-ac94-476a-a428-5b3c333b020a) |
# | N/A | Wilmington, NC | [<div> <img src="attachment:569d5925-53bc-4291-b517-b6e56321df74.jpg" width="100"/> </div>](https://www.petfinder.com/cat/a457116-58875378/nc/wilmington/new-hanover-county-sheriff-animal-services-unit-nc700/) |
# | Forrest | San Francisco, CA | [<div> <img src="attachment:a175bbb6-7176-4c71-8791-16041255ab51.jpg" width="100"/> </div>](https://www.petfinder.com/cat/forrest-58874563/ca/san-francisco/wonder-cat-rescue-ca1021/) |
